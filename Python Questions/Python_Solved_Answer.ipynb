# %% [markdown]
# ### **Ques 1. Write a program that takes a string as input, and counts the frequency of each word in the string, there might be repeated characters in the string. Your task is to find the highest frequency and return the length of the highest-frequency word**

# %%
import string
def freq_of_word(given_string):
  
  spcl_char = "`~!@#$%^&*()_+-=/{}[]*;:?\|',<.>"  #define special char that can appear in a string

  new_string = given_string.lower()      

  for i in given_string:
    if i in spcl_char:
      new_string = given_string.translate(str.maketrans('','',string.punctuation)) # new string with no special character
      break

  words = new_string.split()
  count_words = dict()
  unique_words = set(words)
  for i in unique_words:
    count_words[i] = words.count(i)

  result =sorted(count_words.items(),key= lambda x:x[1], reverse= True)  # sorting the frequency of accurence of word
  # print(result)
  return len(result[0][0])

# %%
## test case 1
# write write write all the number from from from 1 to 100
## driver code
given_string = input("enter any string: ")
length = freq_of_word(given_string)
print("input string : ",given_string)
print(f"length of word = {length}")

# Explanation : most frequent words from given string is write and fromat but corresponding max length is 6
# Out:
# input string :  write write write all the number from from from 1 to 100
# length of word = 5

# %%
## test case 2
# write, write' write all] the number fromat{ fromat} fromat 1 to 100
## driver code
given_string = input("enter any string: ")
length = freq_of_word(given_string)
print("input string : ",given_string)
print(f"length of word = {length}")

# Explanation : most frequent words from given string is "write" and "fromat" but string has many special chars too ignoring that, the corresponding max length of frequent word is 6
# Out:
# input string :  write, write' write all] the number fromat{ fromat} fromat 1 to 100
# length of word = 6

# %%
## test case 3
# WRITE WRITE WRITE all the number FROMAT fromat fromat 1 to 100
## driver code
given_string = input("enter any string: ")
length = freq_of_word(given_string)
print("input string : ",given_string)
print(f"length of word = {length}")

# Explanation : most frequent words from given string is "WRITE" and "fromat or FROMAT" but string is having lower and uppercase both but ignoring that, the corresponding max length of frequent word is 6
# Out:
# input string :  WRITE WRITE WRITE all the number FROMAT fromat fromat 1 to 100
# length of word = 6

# %% [markdown]
# ### **Ques 2. Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if he can remove just one character at the index in the string, and the remaining characters will occur the same number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO.**

# %%
def validate(st):
  try: 
    if len(st) == 0 or len(st) == 1:
      return "YES"
    else:
      string = st.lower() # if string is in mixed case
      d = dict()
      for i in string:    # count the occurence of each char
        if i in d:
          d[i] += 1
        else:
          d[i] = 1
      value = list(d.values()) 

      print(f"freq = {d}")
      # print(f"value list = {value}")
      d1 = {}
      for i in value:               # count the occurence of values of each char
        if i in d1:
          d1[i] += 1
        else:
          d1[i] = 1

      # print(f"count of values in value list={d1}")

      if len(d1) == 1:
        return "YES"

      if (len(d1) == 2 ):
        minfreq = min(d1.keys())
        maxfreq = max(d1.keys())
        # print(f"min= {minfreq} and max= {maxfreq}")
        if d1[maxfreq] == 1 and (maxfreq - minfreq) == 1:
            return 'YES'
        if d1[minfreq] == 1 and minfreq == 1:
            return 'YES'
    
      return "NO"
    
  except Exception as e:
    print("Exception Occured : ", e)

# %%
## test case 1
validate("...")

## Explanation : given string is valid as 'n' is 1 that can be removed so that occurence of other characters are equal.
# Out:
# freq = {'i': 111, 'b': 111, 'f': 111, 'd': 111, 'g': 111, 'a': 111, 'e': 111, 'h': 111, 'c': 111, 'n': 1}
# 'YES'

# %%
## test case 2
validate("aaaabbcc")

## Explanation : given string "aaaabbcc" is not valid as "a" occured 4 times if "a" can be removed from 1 index then occurence of other characters are not equal 
#  {'a': 3, 'b': 2, 'c': 2}.
# Out:
# freq = {'a': 4, 'b': 2, 'c': 2}
# 'NO'

# %%
## test case 3
validate("aabbcd")

## Explanation : given string "aabbcd" is not valid as occurence of char a,b is 2 times and occurence of c,d is 1 times removal of any char from any index will not result into valid string.
# Out:
# freq = {'a': 2, 'b': 2, 'c': 1, 'd': 1}
# 'NO'

# %%
## test case 4
validate("aabbccddeefghi")

## Explanation : given string "aabbccddeefghi" is not valid as occurence of char a,b,c,d,e is 2 times and occurence of f,g,h,i is 1 times removal of any char from any index will not result into valid string.
# Out:
# freq = {'a': 2, 'b': 2, 'c': 2, 'd': 2, 'e': 2, 'f': 1, 'g': 1, 'h': 1, 'i': 1}
# 'NO'

# %%
## test case 5
validate("abc")

## Explanation : given string 'abc' is valid as each character occurence are equal.
# Out:
# freq = {'a': 1, 'b': 1, 'c': 1}
# 'YES'

# %%
## test case 6
validate("a")

## Explanation : given string 'a' is valid one character one time appeared in string.
# Out:
# 'YES'

# %% [markdown]
# ### **Ques 3. Write a program, which would download the data from the provided link, and then read the data and convert that into properly structured data and return it in Excel format.**
#
# Link -  https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json
#
# - id: Identification Number
# - num: Number of the Pokémon in the official Pokédex
# - name: Pokémon name
# - img: URL to an image of this Pokémon
# - type: Pokémon type
# - height: Pokémon height
# - weight: Pokémon weight
# - candy: type of candy used to evolve Pokémon or given when transfered
# - candy_count: amount of candies required to evolve
# - egg: Number of kilometers to travel to hatch the egg
# - spawn_chance: Percentage of spawn chance (NEW)
# - avg_spawns: Number of this pokemon on 10.000 spawns (NEW)
# - spawn_time: Spawns most active at the time on this field. Spawn times are the - same for all time zones and are expressed in local time. (NEW)
# - multipliers: Multipler of Combat Power (CP) for calculating the CP after - - - evolution See below
# - weakness: Types of Pokémon this Pokémon is weak to
# - next_evolution: Number and Name of successive evolutions of Pokémon
# - prev_evolution: Number and Name of previous evolutions of Pokémon

# %%
import json
import csv
from collections import OrderedDict
 
# open json file and store in data
with open("pokedex.json") as json_file:
    data = json.load(json_file)
 
#  list of all pokemons
pokemons = data["pokemon"]
 
#  new file to write data in csv format 
data_file = open('pokemon.csv', 'w')
 
 # create the csv writer object
csv_writer = csv.writer(data_file)
 
 # Counter variable used for writing headers to the CSV file
count = 0

# ordered dict variable to prevent the order of the dict values as some keys are missing
od = OrderedDict()
 
for poke in pokemons:
    if count == 0:
        # Writing headers of CSV file

        header = ['id', 'num', 'name', 'img', 'type', 'height', 'weight', 'candy', 'candy_count', 'egg', 
                  'spawn_chance', 'avg_spawns', 'spawn_time', 'multipliers', 'weaknesses', 'prev_evolution', 'next_evolution']
        csv_writer.writerow(header)
        count += 1

    new = poke

    # missing keys are stored with none value

    for val in header:
        if val not in poke.keys():
            new[val] = "None"
            od[val] = new[val]
        else:
            od[val] = new[val]
    # print(od)
    # Writing data to CSV file
    csv_writer.writerow(od.values())
 
data_file.close()

# %% [markdown]
# ### **QUES 4. Write a program to download the data from the link given below and then read the data and convert the into the proper structure and return it as a CSV file.**
# Link - https://data.nasa.gov/resource/y77d-th95.json
# Note - Write code comments wherever needed for code understanding.
#
# **Excepted Output Data Attributes**
# - Name of Earth Meteorite - string
# - id - ID of Earth Meteorite - int
# - nametype - string
# - recclass - string
# - mass - Mass of Earth Meteorite - float
# - year - Year at which Earth Meteorite was hit - datetime format
# - reclat - float
# - recclong - float
# - point coordinates - list of int

# %%
import pandas as pd

df = pd.read_json("https://data.nasa.gov/resource/y77d-th95.json")
df.head(2)
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   id                           1000 non-null   int64
#  2   nametype                     1000 non-null   object
#  3   recclass                     1000 non-null   object
#  4   mass                         972 non-null    float64
#  5   fall                         1000 non-null   object
#  6   year                         999 non-null    object
#  7   reclat                       988 non-null    float64
#  8   reclong                      988 non-null    float64
#  9   geolocation                  988 non-null    object
#  10  :@computed_region_cbhk_fwbd  133 non-null    float64
#  11  :@computed_region_nnqa_25f4  134 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# ...

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
# Splitting dictionary into separate columns in Pandas DataFrame
df['geolocation'].apply(pd.Series)
df = pd.concat([df, df['geolocation'].apply(pd.Series)], axis=1)

# %%
df.head(1)
# Out:
#      name  id nametype recclass  mass  fall                     year  reclat  \
# 0  Aachen   1    Valid       L5  21.0  Fell  1880-01-01T00:00:00.000  50.775
#
#    reclong                                        geolocation  \
# 0  6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4   type  \
# 0                          NaN                          NaN  Point
#
#          coordinates   0
# 0  [6.08333, 50.775] NaN

# %%
df.drop(columns=['geolocation',':@computed_region_cbhk_fwbd',':@computed_region_nnqa_25f4',0], axis=1, inplace=True)
df.head(1)
# Out:
#      name  id nametype recclass  mass  fall                     year  reclat  \
# 0  Aachen   1    Valid       L5  21.0  Fell  1880-01-01T00:00:00.000  50.775
#
#    reclong   type        coordinates
# 0  6.08333  Point  [6.08333, 50.775]

# %%
df.to_csv("meteorite.csv",index=False)

# %%
df1 = pd.read_csv("meteorite.csv")

# %%
df1.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong   type           coordinates
# 0  1880-01-01T00:00:00.000  50.77500    6.08333  Point     [6.08333, 50.775]
# 1  1951-01-01T00:00:00.000  56.18333   10.23333  Point  [10.23333, 56.18333]
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000  Point      [-113, 54.21667]
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000  Point     [-99.9, 16.88333]
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000  Point   [-64.95, -33.16667]

# %% [markdown]
# ### **QUES 5. Write a program to download the data from the given API link and then extract the following data with proper formatting**
#
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes
#
# Note - Write proper code comments wherever needed for the code understanding
#
# Excepted Output Data Attributes -
# - id - int
# - url - string
# - name - string
# - season - int
# - number - int
# - type - string
# - airdate - date format
# - airtime - 12-hour time format
# - runtime - float
# - average rating - float
# - summary - string without html tags
# - medium image link - string
# - Original image link - string

# %%
import json 
import csv
import pandas as pd

# %%
# open json file and store in data
with open("question_5.json") as json_file:
    data = json.load(json_file)


episode_details = data["_embedded"]["episodes"]

# open file for writing
file = open("episode_details.csv","w")

csv_writer = csv.writer(file)
# Counter variable used for writing
# headers to the CSV file
count = 0
for episode in episode_details:
    if count == 0:
        # Writing headers of CSV file
        header = episode.keys()
        csv_writer.writerow(header)
        count += 1
    
    # Writing data to CSV file
    csv_writer.writerow(episode.values())


file.close()

# %%
df = pd.read_csv("episode_details.csv")
df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
# 1       1       2  regular  2016-10-09   21:00  2016-10-10T01:00:00+00:00
#
#    runtime            rating  \
# 0       68    {'average': 8}
# 1       60  {'average': 7.7}
#
#                                                image  \
# 0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
# 1  <p>Bernard suspects that someone is sabotaging...
#
#                                               _links
# ...

# %%
# converting date to dattime format 
df['airdate'] = pd.to_datetime(df['airdate'])
df['airdate'].astype("datetime64")
# Out:
# 0    2016-10-02
# 1    2016-10-09
# 2    2016-10-16
# 3    2016-10-23
# 4    2016-10-30
# 5    2016-11-06
# 6    2016-11-13
# 7    2016-11-20
# 8    2016-11-27
# 9    2016-12-04
# 10   2018-04-22
# 11   2018-04-29
# 12   2018-05-06
# 13   2018-05-13
# 14   2018-05-20
# 15   2018-05-27
# 16   2018-06-03
# 17   2018-06-10
# 18   2018-06-17
# 19   2018-06-24
# 20   2020-03-15
# 21   2020-03-22
# 22   2020-03-29
# 23   2020-04-05
# 24   2020-04-12
# 25   2020-04-19
# 26   2020-04-26
# 27   2020-05-03
# 28   2022-06-26
# 29   2022-07-03
# 30   2022-07-10
# 31   2022-07-17
# 32   2022-07-24
# 33   2022-07-31
# 34   2022-08-07
# 35   2022-08-14
# Name: airdate, dtype: datetime64[ns]

# %%
df['summary'][24]
# Out:
# '<p>Just say no.</p>'

# %%
#  removing html tags
df['summary'] = df['summary'].apply(lambda x : x.lstrip("<p>") )
df['summary'] = df['summary'].apply(lambda x : x.rstrip("</p>") )
df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type    airdate airtime                   airstamp  \
# 0       1       1  regular 2016-10-02   21:00  2016-10-03T01:00:00+00:00
# 1       1       2  regular 2016-10-09   21:00  2016-10-10T01:00:00+00:00
#
#    runtime            rating  \
# 0       68    {'average': 8}
# 1       60  {'average': 7.7}
#
#                                                image  \
# 0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
# 1  Bernard suspects that someone is sabotaging th...
#
#                                               _links
# ...

# %%
print(type(df['image'][0])) # type is by default str 
df['image'] = df['image'].apply(eval) # Converting type to dict 
print(type(df['image'][0]))  # type is now dict
# Out:
# <class 'str'>
# <class 'dict'>

# %%
# segregating image column == medium and original links

df['image'].apply(pd.Series)
df = pd.concat([df, df['image'].apply(pd.Series)], axis=1)

# %%
df.rename(columns= {"medium" : "medium image link", "original" : "original image link"}, inplace=True)

# %%
df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type    airdate airtime                   airstamp  \
# 0       1       1  regular 2016-10-02   21:00  2016-10-03T01:00:00+00:00
# 1       1       2  regular 2016-10-09   21:00  2016-10-10T01:00:00+00:00
#
#    runtime            rating  \
# 0       68    {'average': 8}
# 1       60  {'average': 7.7}
#
#                                                image  \
# 0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
# 1  Bernard suspects that someone is sabotaging th...
#
#                                               _links  \
# ...

# %%
df.drop(columns=['image','_links','airstamp'], axis=1, inplace=True)

# %%
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type    airdate airtime  runtime          rating  \
# 0       1       1  regular 2016-10-02   21:00       68  {'average': 8}
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link
# 0  https://static.tvmaze.com/uploads/images/origi...

# %%
def convert_24_to_12(time):
    h = int(time[:2])

    h = h % 12

    if h == 0:
        res = "12"
        for i in range(2,5):
            res += time[i]

        return res
    else:
        res = str(h)
        for i in range(2,5):
            res += time[i]

        return res
    
# st = "21:00"
# convert_24_to_12(st)

# %%
df['airtime'] = df['airtime'].apply(convert_24_to_12)

# %%
df['airtime'] = pd.to_datetime(df['airtime'])
df['airtime'].astype("datetime64")
# Out:
# 0    2023-06-01 09:00:00
# 1    2023-06-01 09:00:00
# 2    2023-06-01 09:00:00
# 3    2023-06-01 09:00:00
# 4    2023-06-01 09:00:00
# 5    2023-06-01 09:00:00
# 6    2023-06-01 09:00:00
# 7    2023-06-01 09:00:00
# 8    2023-06-01 09:00:00
# 9    2023-06-01 09:00:00
# 10   2023-06-01 09:00:00
# 11   2023-06-01 09:00:00
# 12   2023-06-01 09:00:00
# 13   2023-06-01 09:00:00
# 14   2023-06-01 09:00:00
# 15   2023-06-01 09:00:00
# 16   2023-06-01 09:00:00
# 17   2023-06-01 09:00:00
# 18   2023-06-01 09:00:00
# 19   2023-06-01 09:00:00
# 20   2023-06-01 09:00:00
# 21   2023-06-01 09:00:00
# 22   2023-06-01 09:00:00
# 23   2023-06-01 09:00:00
# 24   2023-06-01 09:00:00
# 25   2023-06-01 09:00:00
# 26   2023-06-01 09:00:00
# 27   2023-06-01 09:00:00
# 28   2023-06-01 09:00:00
# 29   2023-06-01 09:00:00
# 30   2023-06-01 09:00:00
# 31   2023-06-01 09:00:00
# 32   2023-06-01 09:00:00
# 33   2023-06-01 09:00:00
# 34   2023-06-01 09:00:00
# 35   2023-06-01 09:00:00
# ...

# %%
df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type    airdate             airtime  runtime  \
# 0       1       1  regular 2016-10-02 2023-06-01 09:00:00       68
# 1       1       2  regular 2016-10-09 2023-06-01 09:00:00       60
#
#              rating                                            summary  \
# 0    {'average': 8}  A woman named Dolores is a free spirit in the ...
# 1  {'average': 7.7}  Bernard suspects that someone is sabotaging th...
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
# 1  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link
# 0  https://static.tvmaze.com/uploads/images/origi...
# ...

# %%
type(df['rating'][0])
df['rating'] = df['rating'].apply(eval)
type(df['rating'][0])
# Out:
# dict

# %%
df['ratings'] = df['rating'].apply(lambda x : x['average'])

# %%
df.drop(columns=['rating'], axis = 1, inplace = True)

# %%
df.to_csv("episodes.csv",index= False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   36 non-null     int64
#  1   url                  36 non-null     object
#  2   name                 36 non-null     object
#  3   season               36 non-null     int64
#  4   number               36 non-null     int64
#  5   type                 36 non-null     object
#  6   airdate              36 non-null     datetime64[ns]
#  7   airtime              36 non-null     datetime64[ns]
#  8   runtime              36 non-null     int64
#  9   rating               36 non-null     object
#  10  summary              36 non-null     object
#  11  medium image link    36 non-null     object
#  12  original image link  36 non-null     object
# dtypes: datetime64[ns](2), int64(4), object(7)
# memory usage: 3.8+ KB

# %% [markdown]
# ### **Ques 6 - Using the data from Question 3, write code to analyze the data and answer the following questions**
# Note -->
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations.
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
# 1. Get all Pokemons whose spawn rate is less than 5%
# 2.  Get all Pokemons that have less than 4 weaknesses
# 3.  Get all Pokemons that have no multipliers at all
# 4.  Get all Pokemons that do not have more than 2 evolutions
# 5.  Get all Pokemons whose spawn time is less than 300 seconds.
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
# 6.  Get all Pokemon who have more than two types of capabilities

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy candy_count  \
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy          25
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy         100
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy        None
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy          25
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy         100
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
### task 1   -- Get all Pokemons whose spawn rate is less than 5%

spawn_rate = df[df['spawn_chance'] < 0.05]

plt.figure(figsize=(20,10))
sns.barplot(data= spawn_rate, x='name',y='spawn_chance' )  ## as spawn a continuous variable applying condition to get result
plt.xlabel("Name of Pokemons")
plt.ylabel("Pokemons with spawn rate less than 5%")
plt.xticks(rotation = 90)
plt.show()

# %%
## tesk 2 -- Get all Pokemons that have less than 4 weaknesses

# Pandas will read lists as strings, not as lists.
# to convert the type of list from str to list

x  = 0
for i, l in enumerate(df['weaknesses']):
    if x == 3:
        break
    else:
        print("list",i,"is",type(l))
        x+=1

df['weaknesses'] = df['weaknesses'].apply(eval)

## creating a new column that has number of weaknesses of pokemons

df['weaknesses_length'] = df['weaknesses'].apply(lambda x : len(x))

## checking that type has been converted to list or not

x  = 0
for i, l in enumerate(df['weaknesses']):
    if x == 3:
        break
    else:
        print("list",i,"is",type(l))
        x+=1
# Out:
# list 0 is <class 'str'>
# list 1 is <class 'str'>
# list 2 is <class 'str'>
# list 0 is <class 'list'>
# list 1 is <class 'list'>
# list 2 is <class 'list'>

# %%
df.head(2)
# Out:
#    id  num       name                                               img  \
# 0   1    1  Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2    Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
#
#                   type  height   weight            candy candy_count  \
# 0  ['Grass', 'Poison']  0.71 m   6.9 kg  Bulbasaur Candy          25
# 1  ['Grass', 'Poison']  0.99 m  13.0 kg  Bulbasaur Candy         100
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00      [1.58]
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
#
#                      weaknesses                         prev_evolution  \
# 0  [Fire, Ice, Flying, Psychic]                                   None
# 1  [Fire, Ice, Flying, Psychic]  [{'num': '001', 'name': 'Bulbasaur'}]
#
#                                       next_evolution  weaknesses_length
# ...

# %%
weakness = df[df['weaknesses_length'] < 4]

# %%
plt.figure(figsize=(20,10))
sns.barplot(data= weakness[:50], x='name', y='weaknesses_length') # now weakness length is numerical then we apply condition
plt.xticks(rotation = 90)
plt.xlabel("Name of Pokemons")
plt.ylabel("weaknesses of pokemons")
plt.show()

# %%
## task 3 -- Get all Pokemons that have no multipliers at all
# df['multipliers'] = df['multipliers'].fillna("None")
# df['multipliers'] = df['multipliers'].replace("None",0)

df['multipliers'] = df['multipliers'].fillna(0)

no_multiplier = df[df['multipliers'] == 0]

plt.figure(figsize=(20,10))

sns.scatterplot(data= no_multiplier ,y ='multipliers', x="name" )
plt.xlabel("Name of Pokemons")
plt.ylabel("Pokemons have no multipliers")
plt.xticks(rotation = 90)
plt.show()

# %%
### task 4 -- Get all Pokemons that do not have more than 2 evolutions

# to convert the type of list from str to list
df['next_evolution'] = df['next_evolution'].apply(eval)

## creating a new column that has number of evolutions of pokemons
df['next_evolution_len'] = df['next_evolution'].apply(lambda x : len(x) if type(x) == list else 0 )

evolution = df[df['next_evolution_len'] <= 2]

plt.figure(figsize=(10,20))

sns.scatterplot(data= evolution[:50],x ='next_evolution_len', y ="name" )
plt.xlabel("Name of Pokemons")
plt.ylabel("Pokemons evolution not more than 2")
plt.xticks(rotation = 90)
plt.show()

# %%
# ## task 5 Get all Pokemons whose spawn time is less than 300 seconds.


time_format = "%H:%M:%S"
df['spawn_time'] = df['spawn_time'].fillna("00:00")
df['spawn_time']=df['spawn_time'].apply(lambda x :  str("00:")+str(x) )

df['spawn_time'] = pd.to_datetime(df['spawn_time'], format=time_format)

df['spawn_time_second'] = df['spawn_time'].apply(lambda x : ((x.minute * 60)+ x.second))

spawn_time = df[df['spawn_time_second'] < 300] #filter spawn time less than 300 seconds

plt.figure(figsize=(20,10))

sns.barplot(data= spawn_time,y ='spawn_time_second', x="name" )
plt.xlabel("Name of Pokemons")
plt.ylabel("Pokemons have spawn time less than 300 sec")
plt.xticks(rotation = 90)
plt.show()

# %%
## task 6 -- Get all Pokemon who have more than two types of capabilities

# observation = NO POKEMONS HAVE MORE THAN TWO CAPABILITIES SO iM PLOTTING GRAPH FOR GREATER THAN 1 CAPABILITIES

# to convert the type of list from str to list
df['type'] = df['type'].apply(eval)


## creating a new column that has number of capabilities of pokemon
df['type_len'] = df['type'].apply(lambda x : len(x) )

# observation --> No pokemon has more than two capabilitoes so here is the plot for pokemon more than one capabilities

plt.figure(figsize=(10,10))

sns.scatterplot(data= df[df['type_len'] > 1],y ='type_len', x="name" )
plt.xlabel("Name of Pokemons")
plt.ylabel("Pokemons of more than 2 types")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Conclusion of above question**
# **for condition --> Pokemon who have more than two types of capabilities**
# **observation --> No pokemon has more than two capabilitoes so here is the plot for pokemon more than one capabilities**

# %% [markdown]
# ### **QUES 7. Using the data from Question 4, write code to analyze the data and answer the following questions**
# Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# - Get all the Earth meteorites that fell before the year 2000
# - Get all the earth meteorites co-ordinates who fell before the year 1970
# - Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
import pandas as pd

df = pd.read_csv("meteorite.csv")
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong   type           coordinates
# 0  1880-01-01T00:00:00.000  50.77500    6.08333  Point     [6.08333, 50.775]
# 1  1951-01-01T00:00:00.000  56.18333   10.23333  Point  [10.23333, 56.18333]
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000  Point      [-113, 54.21667]
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000  Point     [-99.9, 16.88333]
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000  Point   [-64.95, -33.16667]

# %%
# extacting year from year column
df['year_fell'] = df['year'].str.split("-").str[0]  
df.head(3)
# Out:
#      name  id nametype recclass      mass  fall                     year  \
# 0  Aachen   1    Valid       L5      21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6     720.0  Fell  1951-01-01T00:00:00.000
# 2    Abee   6    Valid      EH4  107000.0  Fell  1952-01-01T00:00:00.000
#
#      reclat    reclong   type           coordinates year_fell
# 0  50.77500    6.08333  Point     [6.08333, 50.775]      1880
# 1  56.18333   10.23333  Point  [10.23333, 56.18333]      1951
# 2  54.21667 -113.00000  Point      [-113, 54.21667]      1952

# %%
df.isnull().sum()
# Out:
# name            0
# id              0
# nametype        0
# recclass        0
# mass           28
# fall            0
# year            1
# reclat         12
# reclong        12
# type           12
# coordinates    12
# year_fell       1
# dtype: int64

# %%
df[df['year_fell'].isnull()]
# Out:
#                      name     id nametype recclass   mass   fall year  reclat  \
# 37  Northwest Africa 5815  50693    Valid       L5  256.8  Found  NaN     0.0
#
#     reclong   type coordinates year_fell
# 37      0.0  Point      [0, 0]       NaN

# %%
df['year_fell'] = df['year_fell'].fillna(0000)

# %%
# df['year_fell'].fillna(0)
df['year_fell'] = df['year_fell'].astype(int)

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong   type           coordinates  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333  Point     [6.08333, 50.775]
# 1  1951-01-01T00:00:00.000  56.18333   10.23333  Point  [10.23333, 56.18333]
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000  Point      [-113, 54.21667]
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000  Point     [-99.9, 16.88333]
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000  Point   [-64.95, -33.16667]
#
#    year_fell
# 0       1880
# 1       1951
# 2       1952
# 3       1976
# 4       1902

# %%
df['fall'].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# **1. Get all the Earth meteorites that fell before the year 2000**

# %%
import matplotlib.pyplot as plt

## filtering records have meteoriots fell before year 2000
year_df = df[(df['year_fell'] < 2000) & (df['fall'] == 'Fell')]
year_df
# Out:
#           name     id nametype     recclass      mass  fall  \
# 0       Aachen      1    Valid           L5      21.0  Fell
# 1       Aarhus      2    Valid           H6     720.0  Fell
# 2         Abee      6    Valid          EH4  107000.0  Fell
# 3     Acapulco     10    Valid  Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid           L6     780.0  Fell
# ..         ...    ...      ...          ...       ...   ...
# 994   Timochin  24004    Valid           H5   65500.0  Fell
# 995   Tirupati  24009    Valid           H6     230.0  Fell
# 997      Tjabe  24011    Valid           H6   20000.0  Fell
# 998   Tjerebon  24012    Valid           L5   16500.0  Fell
# 999  Tomakovka  24019    Valid          LL6     600.0  Fell
#
#                         year    reclat    reclong   type  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333  Point
# 1    1951-01-01T00:00:00.000  56.18333   10.23333  Point
# 2    1952-01-01T00:00:00.000  54.21667 -113.00000  Point
# ...

# %%
# visualize the meteoriots fell before year 2000

year_val = year_df['year_fell'].value_counts()
x = year_val.index
y = year_val.values

plt.scatter(x, y, s = 10)
plt.xlabel("Year ")
plt.ylabel("meteorites")
plt.show()

# %% [markdown]
# **2. Get all the earth meteorites co-ordinates who fell before the year 1970**

# %%
import matplotlib.pyplot as plt

# filtering  earth meteorites that fell before 1970  

valid_df1 = df[(df['year_fell'] < 1970) & (df['year_fell'] > 1000) & (df['fall'] == 'Fell')]
valid_df1

# filtering  earth meteorites coordinates that fell before 1970  
coordinates = valid_df1['coordinates']
coordinates[:50]

# %%
valid_df1.plot(kind='scatter', x='reclong', y='reclat', s = 8)
plt.xlabel("reclong")
plt.ylabel("reclat")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **3. Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg**

# %%
mass_df = df[(df['mass'] > 10000)]
mass_df
# Out:
#            name     id nametype   recclass      mass  fall  \
# 2          Abee      6    Valid        EH4  107000.0  Fell
# 7          Agen    392    Valid         H5   30000.0  Fell
# 11          Aïr    424    Valid         L6   24000.0  Fell
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  Fell
# 27   Alfianello    466    Valid         L6  228000.0  Fell
# ..          ...    ...      ...        ...       ...   ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  Fell
# 992      Tilden  23998    Valid         L6   74800.0  Fell
# 994    Timochin  24004    Valid         H5   65500.0  Fell
# 997       Tjabe  24011    Valid         H6   20000.0  Fell
# 998    Tjerebon  24012    Valid         L5   16500.0  Fell
#
#                         year    reclat    reclong   type  \
# 2    1952-01-01T00:00:00.000  54.21667 -113.00000  Point
# 7    1814-01-01T00:00:00.000  44.21667    0.61667  Point
# 11   1925-01-01T00:00:00.000  19.08333    8.38333  Point
# ...

# %%
mass_val = mass_df['mass'].value_counts()
x = mass_val.index
y = mass_val.values

plt.scatter(x, y, s = 8)
plt.title("Meteorite falls recorded per mass (kg)")
plt.show()

# %% [markdown]
# ### **QUES 8. Using the data from Question 5, write code the analyze the data and answer the following questions**
# Note -
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# - Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.
# - Get all the episode names, whose average rating is more than 8 for every season
# - Get all the episode names that aired before May 2019
# - Get the episode name from each season with the highest and lowest rating
# - Get the summary for the most popular ( ratings ) episode in every season

# %%
# importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("episodes.csv")
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate              airtime  runtime  \
# 0       1       1  regular  2016-10-02  2023-06-01 09:00:00       68
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link  ratings
# 0  https://static.tvmaze.com/uploads/images/origi...      8.0

# %%
# Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on

avg_rating_of_season_one = df[df['season'] == 1]['ratings'].mean()
avg_rating_of_season_two = df[df['season'] == 2]['ratings'].mean()
avg_rating_of_season_three = df[df['season'] == 3]['ratings'].mean()
avg_rating_of_season_four = df[df['season'] == 4]['ratings'].mean()


print(f"overall ratings for season one is {avg_rating_of_season_one}")
print(f"overall ratings for season two is {avg_rating_of_season_two}")
print(f"overall ratings for season three is {round(avg_rating_of_season_three,2)}")
print(f"overall ratings for season four is {round(avg_rating_of_season_four, 2)}")
# Out:
# overall ratings for season one is 8.09
# overall ratings for season two is 8.0
# overall ratings for season three is 7.78
# overall ratings for season four is 7.54

# %%
sns.countplot(data=df, x = 'ratings', hue='season')
plt.show()

# %%
# Get all the episode names, whose average rating is more than 8 for every season
df[df['ratings'] > 8]['name']
# Out:
# 6                 Trompe L'Oeil
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
sns.scatterplot(data = df[df['ratings'] > 8], y= 'name', x= 'ratings')
plt.show()

# %%
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate              airtime  runtime  \
# 0       1       1  regular  2016-10-02  2023-06-01 09:00:00       68
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link  ratings
# 0  https://static.tvmaze.com/uploads/images/origi...      8.0

# %%
df['airdate'] = pd.to_datetime(df['airdate'], infer_datetime_format=True)
df['airdate'] = df['airdate'].astype("datetime64[ns]")

# %%
# Get all the episode names that aired before May 2019
df[(df['airdate'] < "2019-06-01" )][['name', 'airdate']]
# Out:
#                          name    airdate
# 0                The Original 2016-10-02
# 1                    Chestnut 2016-10-09
# 2                   The Stray 2016-10-16
# 3           Dissonance Theory 2016-10-23
# 4                 Contrapasso 2016-10-30
# 5               The Adversary 2016-11-06
# 6               Trompe L'Oeil 2016-11-13
# 7                 Trace Decay 2016-11-20
# 8   The Well-Tempered Clavier 2016-11-27
# 9          The Bicameral Mind 2016-12-04
# 10         Journey Into Night 2018-04-22
# 11                    Reunion 2018-04-29
# 12            Virtù e Fortuna 2018-05-06
# 13   The Riddle of the Sphinx 2018-05-13
# 14               Akane No Mai 2018-05-20
# 15                Phase Space 2018-05-27
# 16               Les Écorchés 2018-06-03
# 17                    Kiksuya 2018-06-10
# 18            Vanishing Point 2018-06-17
# 19              The Passenger 2018-06-24

# %%
sns.scatterplot(data = df[df['airdate'] < "2019-06-01"], y= 'name', x= 'airdate')
plt.xticks(rotation=90)
plt.show()

# %%
res = df.groupby(["season"]).ratings.agg(['min', 'max'])

# %%
res
# Out:
#         min  max
# season
# 1       7.6  8.7
# 2       7.6  8.7
# 3       7.5  8.0
# 4       7.1  7.8

# %%
res.plot(kind='bar')
plt.show()

# %%
# Get the episode name from each season with the highest and lowest rating
r1 = df[df['season'] == 1][["name","ratings"]].agg(["min","max"])
r2 = df[df['season'] == 2][["name","ratings"]].agg(["min","max"])
r3 = df[df['season'] == 3][["name","ratings"]].agg(["min","max"])
r4 = df[df['season'] == 4][["name","ratings"]].agg(["min","max"])

# %%
df3 = pd.concat([r1,r2,r3,r4], keys=[1,2,3,4],names=["season","min_max"])

# %%
df3
# Out:
#                            name  ratings
# season min_max
# 1      min             Chestnut      7.6
#        max        Trompe L'Oeil      8.7
# 2      min         Akane No Mai      7.6
#        max      Virtù e Fortuna      8.7
# 3      min        Crisis Theory      7.5
#        max      The Winter Line      8.0
# 4      min        Années Folles      7.1
#        max             Zhuangzi      7.8

# %%
# Get the summary for the most popular ( ratings ) episode in every season

# for each season calulating popular
r1 = df[df['season'] == 1][["summary","ratings"]].agg(["max"])
r2 = df[df['season'] == 2][["summary","ratings"]].agg(["max"])
r3 = df[df['season'] == 3][["summary","ratings"]].agg(["max"])
r4 = df[df['season'] == 4][["summary","ratings"]].agg(["max"])

# %%
pd.concat([r1,r2,r3,r4], keys=[1,2,3,4],names=["season","max_rating"]).reset_index(level=[1]).drop(labels=["max_rating"],axis=1)
# Out:
#                                                   summary  ratings
# season
# 1       While William and Dolores travel to the unclai...      8.7
# 2       William pays his recuperating father-in-law se...      8.7
# 3       Time to face the music. Dolores' true intentio...      8.0
# 4           You want to have a drink at a time like this?      7.8

# %%
pd.concat([r1,r2,r3,r4], keys=[1,2,3,4],names=["season","max_rating"]).reset_index(level=[1]).drop(labels=["max_rating"],axis=1).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ### **QUES 9. Write a program to read the data from the following link, perform data analysis and answer the following questions**
# Note -
# 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
# Insights to be drawn -
# - Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# - Get all TESLA cars with the model year, and model type made in Bothell City.
# - Get all the cars that have an electric range of more than 100, and were made after 2015
# - Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

data = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
# VIN = Vehicle Identification Number.
# country = Name of the County from where the data is gathered.
# city = Name of the Cities from where the data is gathered
# state = Name of the State from where the data is gathered.
# postal_code = The postal code from where the data is gathered.
# model_year = Manufacturing year of the model mentioned in the data set.
# make = Manufacturer of the vehicle.
# model_name = Model Name of the mentioned vehicle.
# electric_vehicle_type = Type of the vehicle present in the dataset.
# cafv = Clean Alternative for the data present in this dataset.
# electric_range
# base_msrp
# legislative_district
# dol_vehicle_id
# vehicle_location
# electric_utility
# census_tract_2020

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VIN                    130443 non-null  object
#  1   County                 130443 non-null  object
#  2   City                   130443 non-null  object
#  3   State                  130443 non-null  object
#  4   PostalCode             130443 non-null  int32
#  5   ModelYear              130443 non-null  int64
#  6   Make                   130443 non-null  object
#  7   Model                  130443 non-null  object
#  8   Electric_Vehicle_Type  130443 non-null  object
#  9   CAFV_Eligibility       130443 non-null  object
#  10  Electric_Range         130443 non-null  int64
#  11  Base_MSRP              130443 non-null  int64
#  12  Legislative_District   130443 non-null  object
#  13  DOL_Vehicle_ID         130443 non-null  int64
# ...

# %% [markdown]
# #### **data cleaning**

# %%
data.head(2)
# Out:
#           VIN  County     City State  PostalCode  ModelYear   Make    Model  \
# 0  5YJXCAE26J  Yakima   Yakima    WA     98908.0       2018  TESLA  MODEL X
# 1  JHMZC5F37M  Kitsap  Poulsbo    WA     98370.0       2021  HONDA  CLARITY
#
#                     Electric_Vehicle_Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           CAFV_Eligibility  Electric_Range  Base_MSRP  \
# 0  Clean Alternative Fuel Vehicle Eligible             238          0
# 1  Clean Alternative Fuel Vehicle Eligible              47          0
#
#    Legislative_District  DOL_Vehicle_ID             Vehicle_Location  \
# 0                  14.0       141151601  POINT (-120.56916 46.58514)
# 1                  23.0       171566447  POINT (-122.64681 47.73689)
#
#          Electric_Utility  2020_Census_Tract
# 0              PACIFICORP       5.307700e+10
# 1  PUGET SOUND ENERGY INC       5.303509e+10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VIN                    130443 non-null  object
#  1   County                 130440 non-null  object
#  2   City                   130440 non-null  object
#  3   State                  130443 non-null  object
#  4   PostalCode             130440 non-null  float64
#  5   ModelYear              130443 non-null  int64
#  6   Make                   130443 non-null  object
#  7   Model                  130221 non-null  object
#  8   Electric_Vehicle_Type  130443 non-null  object
#  9   CAFV_Eligibility       130443 non-null  object
#  10  Electric_Range         130443 non-null  int64
#  11  Base_MSRP              130443 non-null  int64
#  12  Legislative_District   130138 non-null  float64
#  13  DOL_Vehicle_ID         130443 non-null  int64
# ...

# %%
#### renaming columns

data = data.rename(columns={'Postal Code': 'PostalCode', 'Model Year': 'ModelYear','Electric Vehicle Type': 'Electric_Vehicle_Type',
'Clean Alternative Fuel Vehicle (CAFV) Eligibility':'CAFV_Eligibility','Electric Range':'Electric_Range', 'Base MSRP':'Base_MSRP', 'Legislative District':'Legislative_District',
'DOL Vehicle ID': 'DOL_Vehicle_ID','Vehicle Location':'Vehicle_Location','Electric Utility':'Electric_Utility','2020 Census Tract':'2020_Census_Tract',
'VIN (1-10)':'VIN'})

# %%
data.head(2)
# Out:
#           VIN  County     City State  PostalCode  ModelYear   Make    Model  \
# 0  5YJXCAE26J  Yakima   Yakima    WA     98908.0       2018  TESLA  MODEL X
# 1  JHMZC5F37M  Kitsap  Poulsbo    WA     98370.0       2021  HONDA  CLARITY
#
#                     Electric_Vehicle_Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           CAFV_Eligibility  Electric_Range  Base_MSRP  \
# 0  Clean Alternative Fuel Vehicle Eligible             238          0
# 1  Clean Alternative Fuel Vehicle Eligible              47          0
#
#    Legislative_District  DOL_Vehicle_ID             Vehicle_Location  \
# 0                  14.0       141151601  POINT (-120.56916 46.58514)
# 1                  23.0       171566447  POINT (-122.64681 47.73689)
#
#          Electric_Utility  2020_Census_Tract
# 0              PACIFICORP       5.307700e+10
# 1  PUGET SOUND ENERGY INC       5.303509e+10

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# Legislative_District     305
# Model                    222
# Vehicle_Location          33
# 2020_Census_Tract          3
# City                       3
# Electric_Utility           3
# PostalCode                 3
# County                     3
# Base_MSRP                  0
# DOL_Vehicle_ID             0
# VIN                        0
# Electric_Range             0
# CAFV_Eligibility           0
# Make                       0
# ModelYear                  0
# State                      0
# Electric_Vehicle_Type      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_462bb_row0_col0, #T_462bb_row0_col1, #T_462bb_row0_col2, #T_462bb_row0_col4, #T_462bb_row7_col3, #T_462bb_row7_col5, #T_462bb_row7_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_462bb_row0_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_462bb_row0_col5, #T_462bb_row0_col6, #T_462bb_row1_col2, #T_462bb_row1_col3, #T_462bb_row1_col4, #T_462bb_row2_col1, #T_462bb_row2_col2, #T_462bb_row2_col4, #T_462bb_row3_col0, #T_462bb_row3_col2, #T_462bb_row3_col3, #T_462bb_row3_col4, #T_462bb_row3_col5, #T_462bb_row4_col2, #T_462bb_row4_col3, #T_462bb_row4_col4, #T_462bb_row5_col2, #T_462bb_row5_col3, #T_462bb_row5_col4, #T_462bb_row6_col2, #T_462bb_row6_col3, #T_462bb_row6_col4, #T_462bb_row7_col2, #T_462bb_row7_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_462bb_row1_col0, #T_462bb_row4_col0, #T_462bb_row5_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.isnull(),yticklabels = False, cbar = False, cmap = 'viridis')
plt.title("Missing null values")
plt.show()

# %%
missing_percentage = (data.isnull().sum().sort_values(ascending = False)/len(data))*100
missing_percentage
# Out:
# Legislative_District     0.233819
# Model                    0.170189
# Vehicle_Location         0.025298
# 2020_Census_Tract        0.002300
# City                     0.002300
# Electric_Utility         0.002300
# PostalCode               0.002300
# County                   0.002300
# Base_MSRP                0.000000
# DOL_Vehicle_ID           0.000000
# VIN                      0.000000
# Electric_Range           0.000000
# CAFV_Eligibility         0.000000
# Make                     0.000000
# ModelYear                0.000000
# State                    0.000000
# Electric_Vehicle_Type    0.000000
# dtype: float64

# %%
# filling null values
data['Electric_Utility'] = data['Electric_Utility'].fillna('Utility Not Avalilable')
data['Legislative_District'] = data['Legislative_District'].fillna('Unknown')
data['Vehicle_Location'] = data['Vehicle_Location'].fillna('Unknown')
data['Model'] = data['Model'].fillna('Unknown')
data['2020_Census_Tract'] = data['2020_Census_Tract'].fillna('Unknown')
data['City'] = data['City'].fillna('Unknown')

# fill null values in the 'Postal Code' column with the mean salary
mean_postcode = data['PostalCode'].mean()
data['PostalCode'] = data['PostalCode'].fillna(mean_postcode)
data['County'] = data['County'].fillna('Unknown')

# %%
missing_percentage = (data.isnull().sum().sort_values(ascending = False)/len(data))*100
missing_percentage
# Out:
# VIN                      0.0
# CAFV_Eligibility         0.0
# Electric_Utility         0.0
# Vehicle_Location         0.0
# DOL_Vehicle_ID           0.0
# Legislative_District     0.0
# Base_MSRP                0.0
# Electric_Range           0.0
# Electric_Vehicle_Type    0.0
# County                   0.0
# Model                    0.0
# Make                     0.0
# ModelYear                0.0
# PostalCode               0.0
# State                    0.0
# City                     0.0
# 2020_Census_Tract        0.0
# dtype: float64

# %%
data['PostalCode'] = data['PostalCode'].astype(int)

# %%
plt.figure(figsize=(15, 6))
heatmap=sns.heatmap(data.corr(),cmap="cividis", annot=True)
heatmap.set_title('Electric Vehicle Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Electric Vehicle Correlation Heatmap')

# %% [markdown]
# #### **Get all the cars and their types that do not qualify for clean alternative fuel vehicle**

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle

task1 = data[data["CAFV_Eligibility"] != 'Clean Alternative Fuel Vehicle Eligible'][["Model", "Electric_Vehicle_Type", "CAFV_Eligibility"]]

# %%
task1.head()
# Out:
#       Model                   Electric_Vehicle_Type  \
# 6    FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7      Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8     C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 11  MODEL Y          Battery Electric Vehicle (BEV)
# 14    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                                      CAFV_Eligibility
# 6               Not eligible due to low battery range
# 7               Not eligible due to low battery range
# 8               Not eligible due to low battery range
# 11  Eligibility unknown as battery range has not b...
# 14              Not eligible due to low battery range

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data[data["CAFV_Eligibility"] != 'Clean Alternative Fuel Vehicle Eligible'][:2000], x="Model",hue="Electric_Vehicle_Type")
plt.xticks(rotation=90)
plt.title("Count of car models that is not eligible for CAFV")
plt.show()

# %% [markdown]
# #### **Get all TESLA cars with the model year, and model type made in Bothell City.**

# %%
task2 = data[(data['City']=="Bothell") & (data['Make'] == "TESLA")][["Make","ModelYear", "Model", "City"]]

# %%
task2.head()
# Out:
#       Make  ModelYear    Model     City
# 39   TESLA       2020  MODEL 3  Bothell
# 217  TESLA       2022  MODEL 3  Bothell
# 218  TESLA       2022  MODEL Y  Bothell
# 222  TESLA       2018  MODEL 3  Bothell
# 292  TESLA       2017  MODEL X  Bothell

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data[(data['City']=="Bothell") & (data['Make'] == "TESLA")], x="Model",hue="ModelYear")
plt.xticks(rotation=90)
plt.title("Count of Tesla car made in Bothel city")
plt.show()

# %% [markdown]
# #### **Get all the cars that have an electric range of more than 100, and were made after 2015**

# %%
task3 = data[(data["Electric_Range"] > 100) & (data["ModelYear"] > 2015)][["Model","Electric_Range","ModelYear"]]

# %%
task3.head()
# Out:
#       Model  Electric_Range  ModelYear
# 0   MODEL X             238       2018
# 2   MODEL 3             220       2019
# 4   MODEL S             210       2017
# 12  MODEL 3             308       2020
# 13  MODEL 3             322       2020

# %%
plt.figure(figsize=(15,5))
sns.barplot(data= data[(data["Electric_Range"] > 100) & (data["ModelYear"] > 2015)], x="Model",y="Electric_Range",hue="ModelYear")
plt.xticks(rotation=90)
plt.title("Cars have electric range morethan 100 and made after 2015")
plt.show()

# %% [markdown]
# #### **Draw plots to show the distribution between city and electric vehicle type**

# %%
task4 = data[["City", "Electric_Vehicle_Type", "ModelYear"]]

# %%
task4.City.unique()

# %%
task4.head()
# Out:
#       City                   Electric_Vehicle_Type  ModelYear
# 0   Yakima          Battery Electric Vehicle (BEV)       2018
# 1  Poulsbo  Plug-in Hybrid Electric Vehicle (PHEV)       2021
# 2  Seattle          Battery Electric Vehicle (BEV)       2019
# 3  Seattle          Battery Electric Vehicle (BEV)       2013
# 4    Lacey          Battery Electric Vehicle (BEV)       2017

# %%
cnt_MkCity = task4.groupby(['City', 'Electric_Vehicle_Type']).size().reset_index(name='Count')
# Group the data by count and Electric_Vehicle_Type, and sum the counts for each group
grouped_data_cty = cnt_MkCity.groupby(['City', 'Electric_Vehicle_Type'])['Count'].sum().reset_index()
# Group the data by city and sum the counts for each city
city_counts = grouped_data_cty.groupby('City')['Count'].sum().reset_index()
make_counts = grouped_data_cty.groupby('Electric_Vehicle_Type')['Count'].sum().reset_index()
# Sort the cities by count in descending order, and select the top 50
top_cities = city_counts.sort_values(by='Count', ascending=False).head(50)
# top_makes = make_counts.sort_values(by='Count', ascending=False)
# Filter the data to only include the top 10 cities
# filtered_data_Cty = grouped_data_cty[grouped_data_cty['City'].isin(top_cities['City']) & grouped_data_cty['Electric_Vehicle_Type'].isin(top_makes['Electric_Vehicle_Type'])]

filtered_data_Cty = grouped_data_cty[grouped_data_cty['City'].isin(top_cities['City']) & grouped_data_cty['Electric_Vehicle_Type']]

# Pivot the data to create a matrix with counties as rows, makes as columns, and counts as values
pivoted_data_cty = filtered_data_Cty.pivot(index='City', columns='Electric_Vehicle_Type',values='Count').fillna(0)
# Create a stacked bar plot of the pivoted data
pivoted_data_cty.plot(kind='bar')
# Set the title and axis labels
plt.title('Electric_Vehicle_Type distribution count per top 10 City')
plt.xlabel('City')
plt.ylabel('Number of Cars')
# Show the plot
plt.show()

# %%
pivoted_data_cty
# Out:
# Electric_Vehicle_Type  Battery Electric Vehicle (BEV)  \
# City
# Anacortes                                         391
# Auburn                                           1027
# Bainbridge Island                                1037
# Bellevue                                         5729
# Bellingham                                       1649
# Bonney Lake                                       558
# Bothell                                          3396
# Bremerton                                         636
# Burien                                            477
# Camas                                             885
# Edmonds                                          1096
# Everett                                          1306
# Federal Way                                       747
# Gig Harbor                                       1127
# Issaquah                                         1730
# Kenmore                                           613
# ...

# %% [markdown]
# ### **Question 10 : Write a program to count the number of verbs, nouns, pronouns, and adjectives in a given particular phrase or paragraph, and return their respective count as a dictionary.**
# Note -
# 1. Write code comments wherever required for code
# 2. You have to write at least 2 additional test cases in which your program will run successfully and provide an explanation for the same.
#
# Input = The school is organising a cultural show His voice is cultured In the first sentence culture means way of life in the second cultural means connected with art literature and music and in the third cultured means sophisticated well mannered.

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pallavi
# [nltk_data]     Prajapati\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Pallavi
# [nltk_data]     Prajapati\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download("word_tokenize")
# Out:
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index
# False

# %%
text = "The school is organising a cultural show His voice is cultured In the first sentence culture means way of life in the second cultural means connected with art literature and music and in the third cultured means sophisticated well mannered"

import nltk


lower_case = text.lower()
tokens = word_tokenize(lower_case)
tags = nltk.pos_tag(tokens)
tags
# Out:
# [('the', 'DT'),
#  ('school', 'NN'),
#  ('is', 'VBZ'),
#  ('organising', 'VBG'),
#  ('a', 'DT'),
#  ('cultural', 'JJ'),
#  ('show', 'NN'),
#  ('his', 'PRP$'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('cultured', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('sentence', 'NN'),
#  ('culture', 'NN'),
#  ('means', 'VBZ'),
#  ('way', 'NN'),
#  ('of', 'IN'),
#  ('life', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('cultural', 'JJ'),
#  ('means', 'NNS'),
#  ('connected', 'VBN'),
#  ('with', 'IN'),
#  ('art', 'JJ'),
#  ('literature', 'NN'),
#  ('and', 'CC'),
#  ('music', 'NN'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('third', 'JJ'),
#  ('cultured', 'JJ'),
#  ('means', 'NNS'),
#  ('sophisticated', 'VBN'),
#  ('well', 'RB'),
#  ('mannered', 'JJ')]

# %%
from collections import Counter
counts = Counter(tag for word, tag in tags)

# %%
counts
# Out:
# Counter({'DT': 5,
#          'NN': 9,
#          'VBZ': 3,
#          'VBG': 1,
#          'JJ': 8,
#          'PRP$': 1,
#          'VBN': 3,
#          'IN': 5,
#          'NNS': 2,
#          'CC': 2,
#          'RB': 1})
